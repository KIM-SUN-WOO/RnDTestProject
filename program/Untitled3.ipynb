# %%
import dataproc

# %%
import importlib
importlib.reload(dataproc)
# Out:
# <module 'dataproc' from 'C:\\Users\\김선우\\Documents\\GitHub\\RnDTestProject\\program\\dataproc.py'>

# %%
A=dataproc.ExampleData('test.xlsx',Dir="./",WindowSize=19)

# %%
A.df
# Out:
#       timestamp    head_x    head_y    head_z   torso_x   torso_y   torso_z  \
# 0    1743993607 -66.57459  346.6133  2153.312 -53.08918 -76.51717  2227.077
# 1    1743993607 -55.37650  341.3134  2148.882 -52.14709 -77.80215  2225.404
# 2    1743993607 -55.37650  341.3134  2148.882 -52.14709 -77.80215  2225.404
# 3    1743993607 -55.37650  341.3134  2148.882 -52.14709 -77.80215  2225.404
# 4    1743993608 -45.28284  330.4109  2149.211 -51.05178 -87.53446  2226.210
# ..          ...       ...       ...       ...       ...       ...       ...
# 442  1743993622 -71.18983  360.3356  2118.724 -50.02530 -57.78058  2173.144
# 443  1743993622 -71.18983  360.3356  2118.724 -50.02530 -57.78058  2173.144
# 444  1743993622 -71.09723  365.8696  2118.778 -50.38910 -49.04067  2167.271
# 445  1743993622 -71.09723  365.8696  2118.778 -50.38910 -49.04067  2167.271
# 446  1743993622 -71.09723  365.8696  2118.778 -50.38910 -49.04067  2167.271
#
# ...

# %%
A.df.shape[0]
# Out:
# 1
