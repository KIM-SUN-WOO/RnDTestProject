# %%
"""
For each example data set, dot the followings step by step
    step 1. Load Example Data
    step 2. Noise reduction
    step 3. Identify the point when the body reaches at the bottom
    step 4. Calculate the following assessment data for each sqat
            1 ) knees move inward, outward (무릎 돌아감 각도 출력)
            2 ) low back arch (허리 휘어짐 정도 출력)
            3 ) torso lean forward (상체 숙여짐 정도 출력)

"""
